# %%
print('hi!!')
# Out:
# hi!!

# %%
metric=0.032
type(metric)
print(type(metric))
metric="现在我将浮点数变为了字符串"
print(type(metric))
metric= [0.032, 0.034, 0.035]
a=1
print(type(metric))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'list'>

# %%
age=18
if age>=18:
    print("你已经成年了")
elif age>=16:
    print("可以承担法律责任")
else:
    print("你还未成年")
# Out:
# 你已经成年了

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a=range(5)

# %%
print(a)
# Out:
# range(0, 5)
